# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-и-план-проекта" data-toc-modified-id="Описание-и-план-проекта-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание и план проекта</a></span></li><li><span><a href="#Приоритизация-гипотез." data-toc-modified-id="Приоритизация-гипотез.-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Приоритизация гипотез.</a></span></li><li><span><a href="#Анализ-A/B-теста" data-toc-modified-id="Анализ-A/B-теста-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Анализ A/B-теста</a></span><ul class="toc-item"><li><span><a href="#Постройте-график-кумулятивной-выручки-по-группам.-Сделайте-выводы-и-предположения." data-toc-modified-id="Постройте-график-кумулятивной-выручки-по-группам.-Сделайте-выводы-и-предположения.-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Постройте график кумулятивной выручки по группам. Сделайте выводы и предположения.</a></span></li><li><span><a href="#Постройте-график-кумулятивного-среднего-чека-по-группам.-Сделайте-выводы-и-предположения." data-toc-modified-id="Постройте-график-кумулятивного-среднего-чека-по-группам.-Сделайте-выводы-и-предположения.-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Постройте график кумулятивного среднего чека по группам. Сделайте выводы и предположения.</a></span></li><li><span><a href="#Постройте-график-относительного-изменения-кумулятивного-среднего-чека-группы-B-к-группе-A.-Сделайте-выводы-и-предположения." data-toc-modified-id="Постройте-график-относительного-изменения-кумулятивного-среднего-чека-группы-B-к-группе-A.-Сделайте-выводы-и-предположения.-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Постройте график относительного изменения кумулятивного среднего чека группы B к группе A. Сделайте выводы и предположения.</a></span></li><li><span><a href="#Постройте-график-кумулятивного-среднего-количества-заказов-на-посетителя-по-группам.-Сделайте-выводы-и-предположения." data-toc-modified-id="Постройте-график-кумулятивного-среднего-количества-заказов-на-посетителя-по-группам.-Сделайте-выводы-и-предположения.-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Постройте график кумулятивного среднего количества заказов на посетителя по группам. Сделайте выводы и предположения.</a></span></li><li><span><a href="#Постройте-график-относительного-изменения-кумулятивного-среднего-количества-заказов-на-посетителя-группы-B-к-группе-A.-Сделайте-выводы-и-предположения." data-toc-modified-id="Постройте-график-относительного-изменения-кумулятивного-среднего-количества-заказов-на-посетителя-группы-B-к-группе-A.-Сделайте-выводы-и-предположения.-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Постройте график относительного изменения кумулятивного среднего количества заказов на посетителя группы B к группе A. Сделайте выводы и предположения.</a></span></li><li><span><a href="#Постройте-точечный-график-количества-заказов-по-пользователям.-Сделайте-выводы-и-предположения." data-toc-modified-id="Постройте-точечный-график-количества-заказов-по-пользователям.-Сделайте-выводы-и-предположения.-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Постройте точечный график количества заказов по пользователям. Сделайте выводы и предположения.</a></span></li><li><span><a href="#Посчитайте-95-й-и-99-й-перцентили-количества-заказов-на-пользователя.-Выберите-границу-для-определения-аномальных-пользователей." data-toc-modified-id="Посчитайте-95-й-и-99-й-перцентили-количества-заказов-на-пользователя.-Выберите-границу-для-определения-аномальных-пользователей.-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Посчитайте 95-й и 99-й перцентили количества заказов на пользователя. Выберите границу для определения аномальных пользователей.</a></span></li><li><span><a href="#Постройте-точечный-график-стоимостей-заказов.-Сделайте-выводы-и-предположения." data-toc-modified-id="Постройте-точечный-график-стоимостей-заказов.-Сделайте-выводы-и-предположения.-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>Постройте точечный график стоимостей заказов. Сделайте выводы и предположения.</a></span></li><li><span><a href="#Посчитайте-95-й-и-99-й-перцентили-стоимости-заказов.-Выберите-границу-для-определения-аномальных-заказов." data-toc-modified-id="Посчитайте-95-й-и-99-й-перцентили-стоимости-заказов.-Выберите-границу-для-определения-аномальных-заказов.-3.9"><span class="toc-item-num">3.9&nbsp;&nbsp;</span>Посчитайте 95-й и 99-й перцентили стоимости заказов. Выберите границу для определения аномальных заказов.</a></span></li><li><span><a href="#Посчитайте-статистическую-значимость-различий-в-среднем-количестве-заказов-на-посетителя-между-группами-по-«сырым»-данным.-Сделайте-выводы-и-предположения." data-toc-modified-id="Посчитайте-статистическую-значимость-различий-в-среднем-количестве-заказов-на-посетителя-между-группами-по-«сырым»-данным.-Сделайте-выводы-и-предположения.-3.10"><span class="toc-item-num">3.10&nbsp;&nbsp;</span>Посчитайте статистическую значимость различий в среднем количестве заказов на посетителя между группами по «сырым» данным. Сделайте выводы и предположения.</a></span></li><li><span><a href="#Посчитайте-статистическую-значимость-различий-в-среднем-чеке-заказа-между-группами-по-«сырым»-данным.-Сделайте-выводы-и-предположения." data-toc-modified-id="Посчитайте-статистическую-значимость-различий-в-среднем-чеке-заказа-между-группами-по-«сырым»-данным.-Сделайте-выводы-и-предположения.-3.11"><span class="toc-item-num">3.11&nbsp;&nbsp;</span>Посчитайте статистическую значимость различий в среднем чеке заказа между группами по «сырым» данным. Сделайте выводы и предположения.</a></span></li><li><span><a href="#Посчитайте-статистическую-значимость-различий-в-среднем-количестве-заказов-на-посетителя-между-группами-по-«очищенным»-данным.-Сделайте-выводы-и-предположения." data-toc-modified-id="Посчитайте-статистическую-значимость-различий-в-среднем-количестве-заказов-на-посетителя-между-группами-по-«очищенным»-данным.-Сделайте-выводы-и-предположения.-3.12"><span class="toc-item-num">3.12&nbsp;&nbsp;</span>Посчитайте статистическую значимость различий в среднем количестве заказов на посетителя между группами по «очищенным» данным. Сделайте выводы и предположения.</a></span></li><li><span><a href="#Посчитайте-статистическую-значимость-различий-в-среднем-чеке-заказа-между-группами-по-«очищенным»-данным.-Сделайте-выводы-и-предположения." data-toc-modified-id="Посчитайте-статистическую-значимость-различий-в-среднем-чеке-заказа-между-группами-по-«очищенным»-данным.-Сделайте-выводы-и-предположения.-3.13"><span class="toc-item-num">3.13&nbsp;&nbsp;</span>Посчитайте статистическую значимость различий в среднем чеке заказа между группами по «очищенным» данным. Сделайте выводы и предположения.</a></span></li><li><span><a href="#Примите-решение-по-результатам-теста-и-объясните-его.-Варианты-решений:-1.-Остановить-тест,-зафиксировать-победу-одной-из-групп.-2.-Остановить-тест,-зафиксировать-отсутствие-различий-между-группами.-3.-Продолжить-тест." data-toc-modified-id="Примите-решение-по-результатам-теста-и-объясните-его.-Варианты-решений:-1.-Остановить-тест,-зафиксировать-победу-одной-из-групп.-2.-Остановить-тест,-зафиксировать-отсутствие-различий-между-группами.-3.-Продолжить-тест.-3.14"><span class="toc-item-num">3.14&nbsp;&nbsp;</span>Примите решение по результатам теста и объясните его. Варианты решений: 1. Остановить тест, зафиксировать победу одной из групп. 2. Остановить тест, зафиксировать отсутствие различий между группами. 3. Продолжить тест.</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Описание и план проекта

# %% [markdown]
# В крупном интернет-магазине отделом маркетинга и аналитиками подготовлен список гипотез для увеличения выручки.
#
# План проекта:
# - приоритезация гипотез
# - проведение A/B-теста
# - анализ результатов A/B-теста.

# %% [markdown]
# ## Приоритизация гипотез.

# %%
import pandas as pd
import datetime as dt
import numpy as np
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
import warnings
import scipy.stats as stats

# %%
df= pd.read_csv('https://code.s3.yandex.net/datasets/hypothesis.csv') #выгрузим инфо о гипотезах
pd.set_option('display.max_colwidth', None)

# %%
df.columns= df.columns.str.lower() #приведем название колонок к нижнему регистру

# %% [markdown]
# Для приоритизации гипотез будем использовать два фреймворка - ICE и RICE.
#
# Фреймворк RICE состоит из четырёх компонент:
# Reach — скольких пользователей затронет изменение, которое вы хотите внести;
# Impact — насколько сильно изменение повлияет на пользователей, их опыт и удовлетворение от продукта;
# Confidence — насколько вы уверены, что это изменение повлияет на пользователей именно так;
# Efforts — сколько стоит протестировать эту гипотезу.
#
# Фреймфорк ICE не учитывает первый параметр Reach .

# %% [markdown]
# Применим фреймворк ICE для приоритизации гипотез. Отсортируем их по убыванию приоритета.

# %%
df['ICE'] = (df['impact']*df['confidence'])/df['efforts']
df[['hypothesis','ICE']].sort_values(by='ICE',ascending=False).round(2)
# Out:
#                                                                                                      hypothesis  \
# 8                                                       Запустить акцию, дающую скидку на товар в день рождения
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 7              Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# 5                      Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов
# ...

# %% [markdown]
# На первом месте гипотеза №8(Запустить акцию, дающую скидку на товар в день рождения), со значением ICE 16,2. Так же в лидерах гипотезы №0 и №7, со значениями 13,3 и 11,2. Все остальные гипотезы имеют значение ICE ниже 10.

# %% [markdown]
# Применим фреймворк RICE для приоритизации гипотез. Отсортируем их по убыванию приоритета.

# %%
df['RICE'] = (df['reach']*df['impact']*df['confidence'])/df['efforts']
df[['hypothesis','RICE']].sort_values(by='RICE',ascending=False)
# Out:
#                                                                                                      hypothesis  \
# 7              Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# 8                                                       Запустить акцию, дающую скидку на товар в день рождения
# 3           Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# ...

# %% [markdown]
# На первом месте гипотеза №7(Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок), со значением  RICE 112. Отрыв от остальных гипотез существенный, на втором месте гипотеза №2 со значением RICE 56,2.

# %% [markdown]
# Приоритезация гипотез при применении RICE изменилась,так получилось,потому что у гипотезы №7(Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок) параметр Reach выше. У гипотезы №7 он равен 10, в то время как у дргих не выше 8. А у гипотезы №8 , лидировавшей при применении ICE  параметр reach и вовсе равен 1. Такая разница понятна, ведь добавление формы подписки на все основные страницы затронет больше пользователей чем акция по скидке на день рождения.

# %% [markdown]
# ## Анализ A/B-теста

# %%
orders = pd.read_csv('https://code.s3.yandex.net/datasets/orders.csv') #выгрузим инфо о заказах
visitors = pd.read_csv('https://code.s3.yandex.net/datasets/visitors.csv')  #выгрузим инфо о пользователях

# %%
orders
# Out:
#       transactionId   visitorId        date  revenue group
# 0        3667963787  3312258926  2019-08-15     1650     B
# 1        2804400009  3642806036  2019-08-15      730     B
# 2        2961555356  4069496402  2019-08-15      400     A
# 3        3797467345  1196621759  2019-08-15     9759     B
# 4        2282983706  2322279887  2019-08-15     2308     B
# ...             ...         ...         ...      ...   ...
# 1192     2662137336  3733762160  2019-08-14     6490     B
# 1193     2203539145   370388673  2019-08-14     3190     A
# 1194     1807773912   573423106  2019-08-14    10550     A
# 1195     1947021204  1614305549  2019-08-14      100     A
# 1196     3936777065  2108080724  2019-08-15   202740     B
#
# [1197 rows x 5 columns]

# %%
#переименнуем столбцы для удобства
orders=orders.rename(columns={'transactionId':'transaction_id',
                             'visitorId':'visitor_id'})

# %%
#посмотрим основную иноформацию и проверим нет ли пропусков
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1197 entries, 0 to 1196
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   transaction_id  1197 non-null   int64
#  1   visitor_id      1197 non-null   int64
#  2   date            1197 non-null   object
#  3   revenue         1197 non-null   int64
#  4   group           1197 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 46.9+ KB

# %%
(orders.duplicated().sum()) #посмотрим количество явных дубликатов в датасете, их нет.
# Out:
# 0

# %%
visitors
# Out:
#           date group  visitors
# 0   2019-08-01     A       719
# 1   2019-08-02     A       619
# 2   2019-08-03     A       507
# 3   2019-08-04     A       717
# 4   2019-08-05     A       756
# ..         ...   ...       ...
# 57  2019-08-27     B       720
# 58  2019-08-28     B       654
# 59  2019-08-29     B       531
# 60  2019-08-30     B       490
# 61  2019-08-31     B       718
#
# [62 rows x 3 columns]

# %%
#посмотрим основную иноформацию и проверим нет ли пропусков
visitors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      62 non-null     object
#  1   group     62 non-null     object
#  2   visitors  62 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 1.6+ KB

# %%
(visitors.duplicated().sum()) #посмотрим количество явных дубликатов в датасете, их нет.
# Out:
# 0

# %%
#дата начала
orders['date'].min()
# Out:
# '2019-08-01'

# %%
#дата окончания
orders['date'].max()
# Out:
# '2019-08-31'

# %%
#посмотрим на сколько групп разделены пользователи
orders['group'].unique()
# Out:
# array(['B', 'A'], dtype=object)

# %%
#посмотрим сколько участников в каждой группе
groups = orders.groupby('group').agg({'visitor_id': 'nunique'})
groups
# Out:
#        visitor_id
# group
# A             503
# B             586

# %% [markdown]
# Пользователи разделены на две группы - А и В. В группе А на 83 пользователя меньше, чем в группе В. Группы не сбалансированы, это может оказать влияние на результаты теста.

# %% [markdown]
# Посмотрим нет ли случаев когда пользователи оказывались в двух группах при тесте.

# %%
# cгруппируем по айди пользователя и посчитаем уникальные группы
unique_group_orders = orders.groupby('visitor_id').agg({'group': 'nunique'})
unique_group_orders['group'].value_counts()
# Out:
# 1    973
# 2     58
# Name: group, dtype: int64

# %% [markdown]
# 58  пользователей  попали сразу в две группы. Это может оказать влияние на результаты теста. Возможно удалить этих пользователей, однако в таблице visitors у нас нет  поля с уникальными айди пользователей и удалить задвоение там будет невозможно. На данном этапе примем решение не удалять пользователей, попавших в две группы, но будем иметь это в уме при дальнейшем анализе. Вероятно была ошибка при подготовке  A/B теста: техническая, человеческий факто, не был проведен A/A тест для  проверки корректности работы теста и распределения пользователей по группам.

# %% [markdown]
#  ### Постройте график кумулятивной выручки по группам. Сделайте выводы и предположения.

# %%
#приведем даты к нужному формату
orders['date'] = orders['date'].map(lambda x: dt.datetime.strptime(x, '%Y-%m-%d'))
visitors['date'] = visitors['date'].map(lambda x: dt.datetime.strptime(x, '%Y-%m-%d'))

# %%
#создадим массив уникальных пар значений дат и групп теста
dates_groups = orders[['date','group']].drop_duplicates()
dates_groups
# Out:
#            date group
# 0    2019-08-15     B
# 2    2019-08-15     A
# 45   2019-08-16     A
# 47   2019-08-16     B
# 55   2019-08-01     A
# ...         ...   ...
# 1068 2019-08-12     A
# 1114 2019-08-13     B
# 1116 2019-08-13     A
# 1149 2019-08-14     B
# 1150 2019-08-14     A
#
# [62 rows x 2 columns]

# %%
#получим агрегированные кумулятивные по дням данные о заказах 
orders_aggregated = dates_groups.apply(lambda x: orders[np.logical_and(orders['date'] <= x['date'], orders['group'] == x['group'])].agg({'date' : 'max', 'group' : 'max', 'transaction_id' : 'nunique', 'visitor_id' : 'nunique', 'revenue' : 'sum'}), axis=1).sort_values(by=['date','group'])

# %%
orders_aggregated
# Out:
#           date group  transaction_id  visitor_id  revenue
# 55  2019-08-01     A              24          20   148579
# 66  2019-08-01     B              21          20   101217
# 175 2019-08-02     A              44          38   242401
# 173 2019-08-02     B              45          43   266748
# 291 2019-08-03     A              68          62   354874
# ..         ...   ...             ...         ...      ...
# 496 2019-08-29     B             596         544  5559398
# 730 2019-08-30     A             545         493  4022970
# 690 2019-08-30     B             620         567  5774631
# 958 2019-08-31     A             557         503  4084803
# 930 2019-08-31     B             640         586  5907760
#
# [62 rows x 5 columns]

# %%
#получим агрегированные кумулятивные по дням данные о посетителях интернет-магазина 
visitors_aggregated = dates_groups.apply(lambda x: visitors[np.logical_and(visitors['date'] <= x['date'], visitors['group'] == x['group'])].agg({'date' : 'max', 'group' : 'max', 'visitors' : 'sum'}), axis=1).sort_values(by=['date','group'])

# %%
#обьединим кумулятивные данные в одной таблице и присвоим ее столбцам понятные названия
cumulative_data = orders_aggregated.merge(visitors_aggregated, left_on=['date', 'group'], right_on=['date', 'group'])

cumulative_data.columns = ['date', 'group', 'orders', 'buyers', 'revenue', 'visitors']

# %%
# датафрейм с кумулятивным количеством заказов и кумулятивной выручкой по дням в группе А
cumulative_revenue_a = cumulative_data[cumulative_data['group']=='A'][['date','revenue', 'orders']]

# датафрейм с кумулятивным количеством заказов и кумулятивной выручкой по дням в группе B
cumulative_revenue_b = cumulative_data[cumulative_data['group']=='B'][['date','revenue', 'orders']]

# %%
#задаем настройки графика
plt.figure(figsize=(10,5))
plt.xticks(rotation=90)
plt.title('Кумулятивная выручка по группам', fontdict={'size':15})
plt.ylabel('Выручка', fontdict={'size': 15})
plt.xlabel('Даты', fontdict={'size': 15})

# Строим график выручки группы А
plt.plot(cumulative_revenue_a['date'], cumulative_revenue_a['revenue'], label='A')

# Строим график выручки группы B
plt.plot(cumulative_revenue_b['date'], cumulative_revenue_b['revenue'], label='B')

plt.legend();

# %% [markdown]
# Все время наблюдения выручка в обеих группах растет.Однако если сначала выручка по группам была приблизтельно равно, то после 17.08.2019 наблюдается резкий рост в группе В, что может свидетельствовать об аномально больших заказах,которые искажают картину.

# %% [markdown]
# ### Постройте график кумулятивного среднего чека по группам. Сделайте выводы и предположения.

# %%
#задаем настройки графика
plt.figure(figsize=(10,5))
plt.xticks(rotation=90)
plt.title('Кумулятивный средний чек по группам', fontdict={'size':15})
plt.ylabel('Количество заказов', fontdict={'size': 15})
plt.xlabel('Даты', fontdict={'size': 15})

#строим график  среднего чека группы А
plt.plot(cumulative_revenue_a['date'], cumulative_revenue_a['revenue']/cumulative_revenue_a['orders'], label='A')
#строим график  среднего чека группы  B
plt.plot(cumulative_revenue_b['date'], cumulative_revenue_b['revenue']/cumulative_revenue_b['orders'], label='B')
plt.legend() ;

# %% [markdown]
# В начале  мы наблюдали рост  средниего чека группы  В и падение в группе А. Однако потом динамика изменилась, группа А начала расти и  к 13.08.2019 обогнала группу В. После 17.08.2019 на графике наблюдается картина аналогичная графику кумулятивной выручки - резкий рост группы В. Это подтверждает предположение, что в группе В были анонмальное высокие заказы, они влияют на результаты теста и в дальнейшем мы их удалим.

# %% [markdown]
# ### Постройте график относительного изменения кумулятивного среднего чека группы B к группе A. Сделайте выводы и предположения.

# %%
# собираем данные в одном датафрейме
merged_сumulative_revenue = cumulative_revenue_a.merge(cumulative_revenue_b, left_on='date', right_on='date', how='left', suffixes=['A', 'B'])

#задаем настройки графика
plt.figure(figsize=(10,5))
plt.xticks(rotation=90)
plt.title('Относительное изменение кумулятивного среднего чека группы  В к группе А', fontdict={'size':15})
plt.xlabel('Даты', fontdict={'size': 15})
plt.ylabel('Относительное изменение', fontdict={'size': 15})

# cтроим отношение средних чеков
plt.plot(merged_сumulative_revenue['date'], (merged_сumulative_revenue['revenueB']/merged_сumulative_revenue['ordersB'])/(merged_сumulative_revenue['revenueA']/merged_сumulative_revenue['ordersA'])-1)

# добавляем ось X
plt.axhline(y=0, color='black', linestyle='--');

# %% [markdown]
# Вновь наблюдаем резкое изменение на графике. В период между 05.08.2019 и 21.08.2019 были наибольшие перепады, сначала падение, а потом резкий рост. Именно в эти даты были аномальные заказы в группе В.

# %% [markdown]
# ### Постройте график кумулятивного среднего количества заказов на посетителя по группам. Сделайте выводы и предположения.

# %%
# считаем кумулятивное среднее количество заказов на посетителя
cumulative_data['avg_ord_per_user'] = cumulative_data['orders']/cumulative_data['visitors']

# отделяем данные по группе A
cumulative_data_a = cumulative_data[cumulative_data['group']=='A']

# отделяем данные по группе B
cumulative_data_b = cumulative_data[cumulative_data['group']=='B']


#задаем настройки графика
plt.figure(figsize=(10,5))
plt.xticks(rotation=90)
plt.title('Кумулятивное среднее количество заказов на посетителя по группам', fontdict={'size':15})
plt.xlabel('Даты', fontdict={'size': 15})
plt.ylabel('Количество заказов', fontdict={'size': 15})

# строим графики
plt.plot(cumulative_data_a['date'], cumulative_data_a['avg_ord_per_user'], label='A')
plt.plot(cumulative_data_b['date'], cumulative_data_b['avg_ord_per_user'], label='B')

plt.legend();

# %% [markdown]
# В начале группа А лидировала, но после 05.08.2019 резко упала, а группа В , наоборот. выросла. Группа В показывает стабильно  лучшие результаты, хотя к конку наблдений разница между группами несколько уменьшилась.

# %% [markdown]
# ### Постройте график относительного изменения кумулятивного среднего количества заказов на посетителя группы B к группе A. Сделайте выводы и предположения.

# %%
merged_сumulative_avg_ord = cumulative_data_a[['date','avg_ord_per_user']].merge(cumulative_data_b[['date','avg_ord_per_user']], left_on='date', right_on='date', how='left', suffixes=['A', 'B'])


#задаем настройки графика
plt.figure(figsize=(10,5))
plt.xticks(rotation=90)
plt.title('Относительное изменение кумулятивного среднего количества заказов на посетителя группы В к группе А', fontdict={'size':15})
plt.xlabel('Даты', fontdict={'size': 15})
plt.ylabel('Относительное изменение', fontdict={'size': 11})
plt.ylim([-0.14,0.25])

plt.plot(merged_сumulative_avg_ord['date'], merged_сumulative_avg_ord['avg_ord_per_userB']/merged_сumulative_avg_ord['avg_ord_per_userA']-1, label="Относительное изменение кумулятивного среднего количества заказов на посетителя");
plt.legend();

plt.axhline(y=0, color='black', linestyle='--');
plt.axhline(y=0.2, color='grey', linestyle='--');

# %% [markdown]
# Между 01.08.2019 и 05.08.2019 наблюдалось падение, однако после 05.08.2019 среднее количество заказов на посетителя группы В стабильно лидирует. После 17.08.2019 наблюдается снижение, но  группа В все равно превосходит группу А.

# %% [markdown]
# ### Постройте точечный график количества заказов по пользователям. Сделайте выводы и предположения.

# %%
#Найдем число заказов по пользователям — создадим датафрейм c двумя столбцами
orders_by_users = (
    orders.groupby('visitor_id', as_index=False)
    .agg({'transaction_id': 'nunique'})
)

orders_by_users.columns = ['visitor_id', 'orders']

# %%
x_values = pd.Series(range(0,len(orders_by_users)))

#задаем настройки графика
plt.figure(figsize=(10,5))
plt.title('Количество заказов по пользователям', fontdict={'size':15})
plt.xlabel('Посетители', fontdict={'size': 11})
plt.ylabel('Количество заказов', fontdict={'size': 11})

plt.scatter(x_values, orders_by_users['orders']);

# %% [markdown]
# Большинство пользователей сделали по 1 заказу. Так же достатоно много тех, кто сделал 2 заказа. И есть несколько выбросов,когда пользователи совершали аномально много заказов - более 10.

# %% [markdown]
# ### Посчитайте 95-й и 99-й перцентили количества заказов на пользователя. Выберите границу для определения аномальных пользователей.

# %%
np.percentile(orders_by_users['orders'], [95, 99])
# Out:
# array([2., 4.])

# %% [markdown]
# Не больше 5 % пользователей сделали больше 2 заказов и не более 1 процента сделали больше 4х заказов. Примем за границу определения аномальных пользователей 99 перцентиль или 4 заказа.

# %% [markdown]
# ### Постройте точечный график стоимостей заказов. Сделайте выводы и предположения.

# %%
x_values = pd.Series(range(0, len(orders['revenue'])))

#задаем настройки графика
plt.figure(figsize=(10,5))
plt.title('Стоимость заказов', fontdict={'size':15})
plt.xlabel('Заказы', fontdict={'size': 11})
plt.ylabel('Стоимость', fontdict={'size': 11})
plt.ticklabel_format(style='plain')

plt.scatter(x_values, orders['revenue']);

# %% [markdown]
# На графике так же видно единичные выбросы, с аномально высокими заказами.

# %%
new=orders.query('revenue < 100000')

# %%
x_values = pd.Series(range(0, len(new['revenue'])))

#задаем настройки графика
plt.figure(figsize=(10,5))
plt.title('Стоимость заказов', fontdict={'size':15})
plt.xlabel('Заказы', fontdict={'size': 11})
plt.ylabel('Стоимость', fontdict={'size': 11})


plt.scatter(x_values, new['revenue']);

# %% [markdown]
#  Если убрать единичные выбросы, то видно, что основная масса заказов - до 20000.

# %% [markdown]
# ### Посчитайте 95-й и 99-й перцентили стоимости заказов. Выберите границу для определения аномальных заказов.

# %%
np.percentile(orders['revenue'], [95, 99])
# Out:
# array([28000. , 58233.2])

# %% [markdown]
# Не более 5% заказов были более 28000 и не более 1%  заказов были более 58233,2. Примем за границу определения аномальных пользователей 99 перцентиль или  58233.

# %% [markdown]
# ### Посчитайте статистическую значимость различий в среднем количестве заказов на посетителя между группами по «сырым» данным. Сделайте выводы и предположения.

# %%
orders_by_users_a = (
    orders[orders['group'] == 'A']
    .groupby('visitor_id', as_index=False)
    .agg({'transaction_id': pd.Series.nunique})
)
orders_by_users_a.columns = ['visitor_id', 'orders']

orders_by_users_b = (
    orders[orders['group'] == 'B']
    .groupby('visitor_id', as_index=False)
    .agg({'transaction_id': pd.Series.nunique})
)
orders_by_users_b.columns = ['visitor_id', 'orders']

# %% [markdown]
#  Сформулируем основную и альтернативные гипотезы.
#
# - Н0 группы А и В равны по среднему количеству заказов на посетителя.
# - Н1 группы А и В не равны по среднему количеству заказов на посетителя.
# - Уровень значимости p-value 0.05
#
# Т.к ранее мы видели большие выбросы, то проведем непараметрический тест Уилкоксона-Манна-Уитни,учитывающий все значения.

# %%
sampleA = pd.concat([orders_by_users_a['orders'],pd.Series(0, index=np.arange(visitors[visitors['group']=='A']['visitors'].sum() - len(orders_by_users_a['orders'])), name='orders')],axis=0)

sampleB = pd.concat([orders_by_users_b['orders'],pd.Series(0, index=np.arange(visitors[visitors['group']=='B']['visitors'].sum() - len(orders_by_users_b['orders'])), name='orders')],axis=0)

print('Уровень значимости p-value:',"{0:.3f}".format(stats.mannwhitneyu(sampleA, sampleB)[1]))

print('Относительное изменеине В к А:',"{0:.3f}".format(sampleB.mean()/sampleA.mean()-1))
# Out:
# Уровень значимости p-value: 0.017
# Относительное изменеине В к А: 0.138

# %% [markdown]
# Уровень значимости p-value 0.017, что меньше 0.05. Нулевую гипотезу отвергаем.
# Группа В выигрывает у группы А на 13,8%

# %% [markdown]
# ### Посчитайте статистическую значимость различий в среднем чеке заказа между группами по «сырым» данным. Сделайте выводы и предположения.

# %% [markdown]
# Сформулируем основную и альтернативные гипотезы.
# - Н0 группы А и В равны по среднему чеку.
# - Н1 группы А и В не равны по среднему чеку.
# Уровень значимости p-value 0.05
# Проведем непараметрический тест Уилкоксона-Манна-Уитни.

# %%
print('Уровень значимости p-value:','{0:.3f}'.format(stats.mannwhitneyu(orders[orders['group']=='A']['revenue'], orders[orders['group']=='B']['revenue'])[1]))
print('Относительное изменеине В к А:', '{0:.3f}'.format(orders[orders['group']=='B']['revenue'].mean()/orders[orders['group']=='A']['revenue'].mean()-1))
# Out:
# Уровень значимости p-value: 0.729
# Относительное изменеине В к А: 0.259

# %% [markdown]
# Уровень значимости p-value 0.729, что больше 0.05. Нет оснований отвергать нулевую гипотезу.
# Группа В выигрывает у группы А на 25,9%

# %% [markdown]
# ### Посчитайте статистическую значимость различий в среднем количестве заказов на посетителя между группами по «очищенным» данным. Сделайте выводы и предположения.

# %% [markdown]
#  Ранее мы видели,что есть аномалии и вероятно они оказывают влияние на результаты теста. Уберем аномальные данны по  границам, которые мы обозначили выше - количество заказов больше 4 и стоимость заказа выше 58233.

# %%
users_with_many_orders = pd.concat(
    [
        orders_by_users_a[orders_by_users_a['orders'] > np.percentile(orders_by_users['orders'], 99)]['visitor_id'],
        orders_by_users_b[orders_by_users_b['orders'] > np.percentile(orders_by_users['orders'], 99)]['visitor_id'],
    ],
    axis=0,
)
users_with_expensive_orders = orders[orders['revenue'] > np.percentile(orders['revenue'], 99)]['visitor_id']
abnormal_users = (
    pd.concat([users_with_many_orders, users_with_expensive_orders], axis=0)
    .drop_duplicates()
    .sort_values()
)

# %% [markdown]
# Посчитаем потери пользователей, которых мы отсекаем как аномальных.

# %%
#количество пользователей совершивших аномальные заказы
abnormal_users.count()
# Out:
# 15

# %%
#количество уникальных пользователей
orders['visitor_id'].value_counts().count()
# Out:
# 1031

# %%
#относительные потери пользователей
abnormal_users.value_counts().count()/len(orders['visitor_id'].unique())
# Out:
# 0.014548981571290009

# %% [markdown]
# Мы теряем всего 15 пользователей из 1031.

# %%
sample_a_filtered = pd.concat([orders_by_users_a[np.logical_not(orders_by_users_a['visitor_id'].isin(abnormal_users))]['orders'],pd.Series(0, index=np.arange(visitors[visitors['group']=='A']['visitors'].sum() - len(orders_by_users_a['orders'])),name='orders')],axis=0)

sample_b_filtered = pd.concat([orders_by_users_b[np.logical_not(orders_by_users_b['visitor_id'].isin(abnormal_users))]['orders'],pd.Series(0, index=np.arange(visitors[visitors['group']=='B']['visitors'].sum() - len(orders_by_users_b['orders'])),name='orders')],axis=0)

# %% [markdown]
# Сформулируем основную и альтернативные гипотезы.
# - Н0 группы А и В равны по среднему количеству заказов на посетителя.
# - Н1 группы А и В не равны по среднему количеству заказов на посетителя.
# - Уровень значимости p-value 0.05
# Проведем непараметрический тест Уилкоксона-Манна-Уитни.

# %%
print('Уровень значимости p-value:','{0:.5f}'.format(stats.mannwhitneyu(sample_a_filtered, sample_b_filtered)[1]))
print('Относительное изменеине В к А:', '{0:.3f}'.format(sample_b_filtered.mean()/sample_a_filtered.mean()-1))
# Out:
# Уровень значимости p-value: 0.01438
# Относительное изменеине В к А: 0.153

# %% [markdown]
# Уровень значимости p-value  стал 0.014, а был 0.017. Однако 0.014 все еще меньше 0.05, значит нулевую гипотезу отвергаем и в этот раз. Группа В выигрывает у группы А на 15,3%

# %% [markdown]
# ### Посчитайте статистическую значимость различий в среднем чеке заказа между группами по «очищенным» данным. Сделайте выводы и предположения.

# %% [markdown]
# Сформулируем основную и альтернативные гипотезы.
# - Н0 группы А и В равны по среднему чеку.
# - Н1 группы А и В не равны по среднему чеку.
# - Уровень значимости p-value 0.05 Проведем непараметрический тест Уилкоксона-Манна-Уитни.

# %%
print('Уровень значимости p-value:',"{0:.3f}".format(stats.mannwhitneyu(
    orders[np.logical_and(
        orders['group']=='A',
        np.logical_not(orders['visitor_id'].isin(abnormal_users)))]['revenue'],
    orders[np.logical_and(
        orders['group']=='B',
        np.logical_not(orders['visitor_id'].isin(abnormal_users)))]['revenue'])[1]))

print('Относительное изменение В к А:',"{0:.3f}".format(
    orders[np.logical_and(orders['group']=='B',np.logical_not(orders['visitor_id'].isin(abnormal_users)))]['revenue'].mean()/
    orders[np.logical_and(orders['group']=='A',np.logical_not(orders['visitor_id'].isin(abnormal_users)))]['revenue'].mean() - 1))
# Out:
# Уровень значимости p-value: 0.851
# Относительное изменение В к А: -0.006

# %% [markdown]
# Уровень значимости p-value 0,851, а был 0.729, однако он все еще больше 0.05. Вновь нет оснований отвергать нулевую гипотезу. Однако группа  В совсем немного проиграла группе А на 0,6%.  При проведении теста на сырых данных группа В выигрывала. Это объясняется тем, что именно в группе В  были аномально высокие заказы.

# %% [markdown]
# ### Примите решение по результатам теста и объясните его. Варианты решений: 1. Остановить тест, зафиксировать победу одной из групп. 2. Остановить тест, зафиксировать отсутствие различий между группами. 3. Продолжить тест.

# %% [markdown]
# По сырым данным и очищенным данным существует статистически значимое различие между группами в среднем количестве заказов на посетителя. Лидирует группа В (на 13,8%  при сырых данных и на 15,3%   при очищенных данных)
#
# При анализе среднего чека между группами наблюдается статистически значимое различие и по сырым и по очищенным даннным. Однако по сырым данным выигрывает группа В на 25,9%, а при очищенных данных даже немного проигрывает - на 0,6%.
#
# По графику относительного изменения кумулятивного среднего количества заказов на посетителя группы B к группе A мы видели, что группа В превосходит группу А.
#
# Группа В показывает результаты лучше, чем группа А. Принимаем решение остановить тест и зафиксировать победу группы В. Однако, стоит помнить,что было 58 пользователей попавших в обе группы при проведении теста и это могло несколько исказить финальные результаты.
